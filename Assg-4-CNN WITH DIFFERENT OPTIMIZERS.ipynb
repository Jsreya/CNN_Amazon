# %%
import os
import cv2, keras
from keras.utils import np_utils
from keras.utils.vis_utils import plot_model
from keras.models import Sequential
from keras.layers import Dense,Conv2D,MaxPooling2D,Flatten,Dropout,Activation
from keras.optimizers import SGD,RMSprop,Adam,Nadam

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import ModelCheckpoint as MCP ,EarlyStopping as ESP, ReduceLROnPlateau as RLP

from keras import backend as K
K.set_image_data_format("channels_last")
# Out:
# Using TensorFlow backend.

# %%
path=r'C:\Users\hp\Amazon\Augmented\aug'
dir = os.listdir(path)
dir
# Out:
# ['SAREE', 'SHIRT', 'TSHIRT']

# %%
height=128
weight=128
channel=1

# %%
#creating a list to store the images extracted         
imgs=[]
for ds in dir:
    img_list=os.listdir(path+'/'+ ds)
    print ('Extracting images from',(ds))
    
    for i in img_list:
        input_img=cv2.imread(path + '/'+ ds + '/'+ i )
        input_img=cv2.cvtColor(input_img, cv2.COLOR_BGR2GRAY)
        img_resize=cv2.resize(input_img,(128,128))
        imgs.append(img_resize)
           
img_data = np.array(imgs).astype('float32')
img_data =img_data/255 #normalization

print (img_data.shape)
# Out:
# Extracting images from SAREE
# Extracting images from SHIRT
# Extracting images from TSHIRT
# (1800, 128, 128)

# %%
#checking channel configuration
if channel==1:
    if K.image_data_format()==("channels_first"):
    
        img_data= np.expand_dims(img_data, axis=1) 
        print("Theano ordering has been used /n")
        print (img_data.shape)
    else:
        img_data= np.expand_dims(img_data, axis=3) 
        print("Tensorflow ordering has been used")
        print (img_data.shape)
else:
    if K.image_data_format()==("channels_first"):
        img_data=np.rollaxis(img_data,3,1) 
        print (img_data.shape)
# Out:
# Tensorflow ordering has been used
# (1800, 128, 128, 1)

# %%
classes=3
class_name=["SAREE","SHIRT",'TSHIRT']
sample_length=img_data.shape[0]

labels = np.ones((sample_length,),dtype="int64") #it'll create a matrix of 1*1

#assigning values, we know that we have 600 images in each folder so assigning values according to them

labels[0:600]=0
labels[600:1200]=1
labels[1200:1800]=2

# %%
#using one_hot encoding
Y=np_utils.to_categorical(labels,classes)

# %%
#using shuffle and train_test_split methods of sklearn for shuffling and splitting the dataset
x,y = shuffle(img_data,Y, random_state=4)

# Splitting the dataset in 80_20 ratio 
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=20)
#splitting the dataset into 80:20 will give 1440 images for training and 360 for testing

# %%
print("Shape of x_train:\t",x_train.shape)
print("\nShape of x_test:\t",x_test.shape)
print("\nShape of y_train:\t",y_train.shape)
print("\nShape of y_test:\t",y_test.shape)
# Out:
# Shape of x_train:	 (1440, 128, 128, 1)
#
# Shape of x_test:	 (360, 128, 128, 1)
#
# Shape of y_train:	 (1440, 3)
#
# Shape of y_test:	 (360, 3)

# %%
ip_shape=img_data[0].shape
ip_shape
#here we have single channel images of 128*128 resolution
# Out:
# (128, 128, 1)

# %%
#BUILDING THE LAYOUT OF CNN MODEL

m=Sequential(name="SCRAPPED_IMAGE_DATASET")
m.add(Conv2D(32,(3,3),name="Conv_1",activation="relu",kernel_initializer='he_uniform',padding='same',input_shape=ip_shape))
m.add(MaxPooling2D(pool_size = (2,2)))

m.add(Conv2D(64,(3,3),name="Conv_2",activation="relu",kernel_initializer='he_uniform',padding='same'))
m.add(MaxPooling2D(pool_size = (2,2)))      
m.add(Dropout(0.5))
      
m.add(Conv2D(64, (3, 3), activation='relu',name="Conv_3" ,kernel_initializer='he_uniform', padding='same'))
m.add(MaxPooling2D((2, 2)))


m.add(Flatten())
      
m.add(Dense(64, activation='relu', kernel_initializer='he_uniform',name="HIDDEN_1"))
m.add(Dense(128, activation='relu', kernel_initializer='he_uniform',name="HIDDEN_2"))    
m.add(Dropout(0.5))
m.add(Dense(3, activation='softmax',name="OUTPUT"))
print("\nSummary:",m.summary())
# Out:
# Model: "SCRAPPED_IMAGE_DATASET"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Conv_1 (Conv2D)              (None, 128, 128, 32)      320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 64, 64, 32)        0
# _________________________________________________________________
# Conv_2 (Conv2D)              (None, 64, 64, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 32, 32, 64)        0
# _________________________________________________________________
# Conv_3 (Conv2D)              (None, 32, 32, 64)        36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 16384)             0
# _________________________________________________________________
# HIDDEN_1 (Dense)             (None, 64)                1048640
# _________________________________________________________________
# HIDDEN_2 (Dense)             (None, 128)               8320
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# OUTPUT (Dense)               (None, 3)                 387
# =================================================================
# Total params: 1,113,091
# Trainable params: 1,113,091
# Non-trainable params: 0
# _________________________________________________________________
#
# Summary: None

# %%
#checking model configuration
m.get_config()
# Out:
# {'name': 'SCRAPPED_IMAGE_DATASET',
#  'layers': [{'class_name': 'Conv2D',
#    'config': {'name': 'Conv_1',
#     'trainable': True,
#     'batch_input_shape': (None, 128, 128, 1),
#     'dtype': 'float32',
#     'filters': 32,
#     'kernel_size': (3, 3),
#     'strides': (1, 1),
#     'padding': 'same',
#     'data_format': 'channels_last',
#     'dilation_rate': (1, 1),
#     'activation': 'relu',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'VarianceScaling',
#      'config': {'scale': 2.0,
#       'mode': 'fan_in',
#       'distribution': 'uniform',
#       'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None}},
#   {'class_name': 'MaxPooling2D',
#    'config': {'name': 'max_pooling2d',
#     'trainable': True,
#     'dtype': 'float32',
#     'pool_size': (2, 2),
#     'padding': 'valid',
#     'strides': (2, 2),
#     'data_format': 'channels_last'}},
#   {'class_name': 'Conv2D',
#    'config': {'name': 'Conv_2',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 64,
#     'kernel_size': (3, 3),
#     'strides': (1, 1),
#     'padding': 'same',
#     'data_format': 'channels_last',
#     'dilation_rate': (1, 1),
#     'activation': 'relu',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'VarianceScaling',
#      'config': {'scale': 2.0,
#       'mode': 'fan_in',
#       'distribution': 'uniform',
#       'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None}},
#   {'class_name': 'MaxPooling2D',
#    'config': {'name': 'max_pooling2d_1',
#     'trainable': True,
#     'dtype': 'float32',
#     'pool_size': (2, 2),
#     'padding': 'valid',
#     'strides': (2, 2),
#     'data_format': 'channels_last'}},
#   {'class_name': 'Dropout',
#    'config': {'name': 'dropout',
#     'trainable': True,
#     'dtype': 'float32',
#     'rate': 0.5,
#     'noise_shape': None,
#     'seed': None}},
#   {'class_name': 'Conv2D',
#    'config': {'name': 'Conv_3',
#     'trainable': True,
#     'dtype': 'float32',
#     'filters': 64,
#     'kernel_size': (3, 3),
#     'strides': (1, 1),
#     'padding': 'same',
#     'data_format': 'channels_last',
#     'dilation_rate': (1, 1),
#     'activation': 'relu',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'VarianceScaling',
#      'config': {'scale': 2.0,
#       'mode': 'fan_in',
#       'distribution': 'uniform',
#       'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None}},
#   {'class_name': 'MaxPooling2D',
#    'config': {'name': 'max_pooling2d_2',
#     'trainable': True,
#     'dtype': 'float32',
#     'pool_size': (2, 2),
#     'padding': 'valid',
#     'strides': (2, 2),
#     'data_format': 'channels_last'}},
#   {'class_name': 'Flatten',
#    'config': {'name': 'flatten',
#     'trainable': True,
#     'dtype': 'float32',
#     'data_format': 'channels_last'}},
#   {'class_name': 'Dense',
#    'config': {'name': 'HIDDEN_1',
#     'trainable': True,
#     'dtype': 'float32',
#     'units': 64,
#     'activation': 'relu',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'VarianceScaling',
#      'config': {'scale': 2.0,
#       'mode': 'fan_in',
#       'distribution': 'uniform',
#       'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None}},
#   {'class_name': 'Dense',
#    'config': {'name': 'HIDDEN_2',
#     'trainable': True,
#     'dtype': 'float32',
#     'units': 128,
#     'activation': 'relu',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'VarianceScaling',
#      'config': {'scale': 2.0,
#       'mode': 'fan_in',
#       'distribution': 'uniform',
#       'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None}},
#   {'class_name': 'Dropout',
#    'config': {'name': 'dropout_1',
#     'trainable': True,
#     'dtype': 'float32',
#     'rate': 0.5,
#     'noise_shape': None,
#     'seed': None}},
#   {'class_name': 'Dense',
#    'config': {'name': 'OUTPUT',
#     'trainable': True,
#     'dtype': 'float32',
#     'units': 3,
#     'activation': 'softmax',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'GlorotUniform',
#      'config': {'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None}}],
#  'build_input_shape': TensorShape([None, 128, 128, 1])}

# %% [markdown]
# compiling the  model with SGD as optimizer with momentum & callbacks

# %%
lr=(0.001,0.01,0.025)
for i in (lr):
    print("AT LEARNING RATE",i)
    print("__"*15)
    print()     
    opt = SGD(learning_rate=i, momentum=0.9,nesterov=False)
    m.compile(optimizer=opt, loss="categorical_crossentropy", metrics=['accuracy'])
    
 #defining the callbacks   
    check= MCP(r"C:\Users\hp\Amazon\Assing-4\garment_MCP_sgd_momt"+str(i)+".h5",
          monitor='val_loss', verbose=1,save_best_only=True,save_weights_only=False, mode='min')

    early=ESP(monitor='val_loss', min_delta=0, patience=4, verbose=1, mode='min',baseline=None, restore_best_weights=True)
    rlp=RLP(monitor='val_loss',factor=0.1, patience=3, verbose=1, mode='min',min_delta=0)
    cb=[early,check,rlp]
    
#training the dataset
    sgd_momt = m.fit(x_train,y_train,batch_size =18,epochs=20,steps_per_epoch=np.floor(len(x_train)//20),
                     validation_data = (x_test, y_test),callbacks=cb)

#predicting the results for test dataset
    print("\npredicting the model performance wrt test dataset")
    prediction= m.evaluate(x_test, y_test)
    prediction 
    print("\nPrediction_TEST LOSS:\t",prediction[0]*100)
    print("\nPrediction_TEST ACCURACY:\t",prediction[1]*100)
    print()
    
    
    
#visualization
   
    record= sgd_momt.history
    loss=record['loss']
    acc=record['accuracy']
    valid_loss=record['val_loss']
    val_acu=record['val_accuracy']
    epoch=range(1,len(loss)+1)
    
    #PLOTTING ACCURACY VALUES
    print('Accuracy Value')
    plt.figure(figsize=(9,4),dpi=120)
    sns.set(context='talk',style='whitegrid',palette='dark',font='monospace',font_scale=0.5)
    l1=plt.plot(epoch,acc,label="TRAIN ACCURACY")
    l2=plt.plot(epoch,val_acu,label="TEST ACCURACY")

    plt.setp(l1,color='fuchsia',marker="p",linewidth=2.1)
    plt.setp(l2,color='greenyellow',marker="v",linewidth=2.1)

    plt.xlabel('\nEPOCH',weight='bold')
    plt.ylabel('ACCURACY\n',weight='bold')
    plt.legend(fancybox=True, framealpha=0.9, shadow=True, borderpad=0.7,bbox_to_anchor=(0., 1.02, 1., .102), loc='lower left',
           ncol=2, mode="expand", borderaxespad=0.1)
    
    plt.show()
    
    
#PLOTTING LOSS VALUES
    print("\nLOSS VALUES")
    plt.figure(figsize=(9,4),dpi=120)
    sns.set(context='talk',style='whitegrid',palette='dark',font='monospace',font_scale=0.5)
    l1=plt.plot(epoch,loss,label="TRAIN LOSS")
    l2=plt.plot(epoch,valid_loss,label="TEST LOSS")

    plt.setp(l1,color='aqua',marker="x",linewidth=2.1)
    plt.setp(l2,color='orange',marker="D",linewidth=2.1)

    plt.xlabel('\nEPOCH',weight='bold')
    plt.ylabel('LOSS\n',weight='bold')
    plt.legend(fancybox=True, framealpha=0.9, shadow=True, borderpad=0.7,bbox_to_anchor=(0., 1.02, 1., .102), loc='lower left',
           ncol=2, mode="expand", borderaxespad=0.1)
    
    plt.show()
    
    print()
# Out:
# AT LEARNING RATE 0.001
# ______________________________
#
# Epoch 1/20
# 72/72 [==============================] - ETA: 0s - loss: 1.2354 - accuracy: 0.4684
# Epoch 00001: val_loss improved from inf to 0.87714, saving model to C:\Users\mishr\CNN\p4_saved_model\garment_MCP_sgd_momt0
20
# 72/72 [==============================] - ETA: 0s - loss: 0.1401 - accuracy: 0.9375Restoring model weights from the end of the best epoch.
#
# Epoch 00014: val_loss did not improve from 0.30750
# 72/72 [==============================] - 47s 651ms/step - loss: 0.1401 - accuracy: 0.9375 - val_loss: 0.3298 - val_accuracy: 0.8861 - lr: 1.0000e-03
# Epoch 00014: early stopping
#
# predicting the model performance wrt test dataset
# 12/12 [==============================] - 3s 261ms/step - loss: 0.3075 - accuracy: 0.8444
#
# Prediction_TEST LOSS:	 30.750039219856262
#
# Prediction_TEST ACCURACY:	 84.44444537162781
#
# Accuracy Value
# LOSS VALUES
# AT LEARNING RATE 0.025
# ______________________________
#
# Epoch 1/20
# 72/72 [==============================] - ETA: 0s - loss: 0.3672 - accuracy: 0.8333
# Epoch 00001: val_loss improved from inf to 0.63023, saving model to C:\Users\mishr\CNN\p4_saved_model\garment_MCP_sgd_momt0.025.h5
# 72/72 [==============================] - 46s 638ms/step - loss: 0.3672 - accuracy: 0.8333 - val_loss: 0.6302 - val_accuracy: 0.7111 - lr: 0.0250
# Epoch 2/20
# 72/72 [==============================] - ETA: 0s - loss: 0.3914 - accuracy: 0.8333
# Epoch 00002: val_loss improved from 0.63023 to 0.46876, saving model to C:\Users\mishr\CNN\p4_saved_model\garment_MCP_sgd_momt0.025.h5
# 72/72 [==============================] - 45s 625ms/step - loss: 0.3914 - accuracy: 0.8333 - val_loss: 0.4688 - val_accuracy: 0.7639 - lr: 0.0250
# Epoch 3/20
# 72/72 [==============================] - ETA: 0s - loss: 0.3977 - accuracy: 0.8333
# Epoch 00003: val_loss improved from 0.46876 to 0.43346, saving model to C:\Users\mishr\CNN\p4_saved_model\garment_MCP_sgd_momt0.025.h5
# 72/72 [==============================] - 45s 619ms/step - loss: 0.3977 - accuracy: 0.8333 - val_loss: 0.4335 - val_accuracy: 0.8056 - lr: 0.0250
# Epoch 4/20
# 72/72 [==============================] - ETA: 0s - loss: 0.4100 - accuracy: 0.8187
# Epoch 00004: val_loss did not improve from 0.43346
# 72/72 [==============================] - 44s 614ms/step - loss: 0.4100 - accuracy: 0.8187 - val_loss: 0.4971 - val_accuracy: 0.7917 - lr: 0.0250
# Epoch 5/20
# 72/72 [==============================] - ETA: 0s - loss: 0.3583 - accuracy: 0.8434
# Epoch 00005: val_loss did not improve from 0.43346
# 72/72 [==============================] - 44s 617ms/step - loss: 0.3583 - accuracy: 0.8434 - val_loss: 0.4962 - val_accuracy: 0.7917 - lr: 0.0250
# Epoch 6/20
# 72/72 [==============================] - ETA: 0s - loss: 0.3957 - accuracy: 0.8264
# Epoch 00006: val_loss did not improve from 0.43346
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.002500000037252903.
# 72/72 [==============================] - 44s 616ms/step - loss: 0.3957 - accuracy: 0.8264 - val_loss: 0.6195 - val_accuracy: 0.7667 - lr: 0.0250
# Epoch 7/20
# 72/72 [==============================] - ETA: 0s - loss: 0.3746 - accuracy: 0.8588
# Epoch 00007: val_loss improved from 0.43346 to 0.41983, saving model to C:\Users\mishr\CNN\p4_saved_model\garment_MCP_sgd_momt0.025.h5
# 72/72 [==============================] - 45s 618ms/step - loss: 0.3746 - accuracy: 0.8588 - val_loss: 0.4198 - val_accuracy: 0.8194 - lr: 0.0025
# Epoch 8/20
# 72/72 [==============================] - ETA: 0s - loss: 0.2591 - accuracy: 0.8704
# Epoch 00008: val_loss improved from 0.41983 to 0.39220, saving model to C:\Users\mishr\CNN\p4_saved_model\garment_MCP_sgd_momt0.025.h5
# 72/72 [==============================] - 44s 616ms/step - loss: 0.2591 - accuracy: 0.8704 - val_loss: 0.3922 - val_accuracy: 0.8417 - lr: 0.0025
# Epoch 9/20
# 72/72 [==============================] - ETA: 0s - loss: 0.2351 - accuracy: 0.8819
# Epoch 00009: val_loss improved from 0.39220 to 0.37473, saving model to C:\Users\mishr\CNN\p4_saved_model\garment_MCP_sgd_momt0.025.h5
# 72/72 [==============================] - 44s 614ms/step - loss: 0.2351 - accuracy: 0.8819 - val_loss: 0.3747 - val_accuracy: 0.8472 - lr: 0.0025
# Epoch 10/20
# 72/72 [==============================] - ETA: 0s - loss: 0.2041 - accuracy: 0.8897
# Epoch 00010: val_loss improved from 0.37473 to 0.37327, saving model to C:\Users\mishr\CNN\p4_saved_model\garment_MCP_sgd_momt0.025.h5
# 72/72 [==============================] - 45s 627ms/step - loss: 0.2041 - accuracy: 0.8897 - val_loss: 0.3733 - val_accuracy: 0.8611 - lr: 0.0025
# Epoch 11/20
# 72/72 [==============================] - ETA: 0s - loss: 0.1871 - accuracy: 0.8935
# Epoch 00011: val_loss did not improve from 0.37327
# 72/72 [==============================] - 44s 617ms/step - loss: 0.1871 - accuracy: 0.8935 - val_loss: 0.3842 - val_accuracy: 0.8611 - lr: 0.0025
# Epoch 12/20
# 72/72 [==============================] - ETA: 0s - loss: 0.2049 - accuracy: 0.8966
# Epoch 00012: val_loss did not improve from 0.37327
# 72/72 [==============================] - 44s 612ms/step - loss: 0.2049 - accuracy: 0.8966 - val_loss: 0.3878 - val_accuracy: 0.8556 - lr: 0.0025
# Epoch 13/20
# 72/72 [==============================] - ETA: 0s - loss: 0.1840 - accuracy: 0.8974
# Epoch 00013: val_loss did not improve from 0.37327
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.00024999999441206456.
# 72/72 [==============================] - 44s 605ms/step - loss: 0.1840 - accuracy: 0.8974 - val_loss: 0.3936 - val_accuracy: 0.8583 - lr: 0.0025
# Epoch 14/20
# 72/72 [==============================] - ETA: 0s - loss: 0.1858 - accuracy: 0.8981Restoring model weights from the end of the best epoch.
#
# Epoch 00014: val_loss did not improve from 0.37327
# 72/72 [==============================] - 44s 612ms/step - loss: 0.1858 - accuracy: 0.8981 - val_loss: 0.3940 - val_accuracy: 0.8611 - lr: 2.5000e-04
# Epoch 00014: early stopping
#
# predicting the model performance wrt test dataset
# 12/12 [==============================] - 3s 258ms/step - loss: 0.3733 - accuracy: 0.8611
#
# Prediction_TEST LOSS:	 37.32712268829346
#
# Prediction_TEST ACCURACY:	 86.11111044883728
#
# Accuracy Value
# LOSS VALUES

# %% [markdown]
# **compiling the model with SGD  with momentum and nestrov with callbacks**

# %%
lr=(0.001,0.01,0.025)
for i in (lr):
    print("AT LEARNING RATE",i)
    print("__"*15)
    print()     
    opt = SGD(learning_rate=i, momentum=0.9,nesterov=True)
    m.compile(optimizer=opt, loss="categorical_crossentropy", metrics=['accuracy'])
    
#defining the callbacks    
    check= MCP(r"C:\Users\mishr\CNN\p4_saved_model\garment_MCP_sgd_mometum_nestrov"+str(i)+".h5",
          monitor='val_loss', verbose=1,save_best_only=True,save_weights_only=False, mode='min')

    early=ESP(monitor='val_loss', min_delta=0, patience=4, verbose=1, mode='min',baseline=None, restore_best_weights=True)

    rlp=RLP(monitor='val_loss',factor=0.1, patience=3, verbose=1, mode='min',min_delta=0)


    cb=[early,check,rlp]
    
#training the dataset
    sgd_momt_nest = m.fit(x_train,y_train,batch_size =18,epochs=20,steps_per_epoch=np.floor(len(x_train)//20),
                     validation_data = (x_test, y_test),callbacks=cb)

#predicting the results for test dataset
    print("\npredicting the model performance wrt test dataset")
    prediction= m.evaluate(x_test, y_test)
    prediction 
    print("\nPrediction_TEST LOSS:\t",prediction[0]*100)
    print("\nPrediction_TEST ACCURACY:\t",prediction[1]*100)
    print()
    
    #visualization
   
       
    
#visualization
   
    record= sgd_momt_nest.history
    loss=record['loss']
    acc=record['accuracy']
    valid_loss=record['val_loss']
    val_acu=record['val_accuracy']
    epoch=range(1,len(loss)+1)
    
    #PLOTTING ACCURACY VALUES
    print('Accuracy Value')
    plt.figure(figsize=(9,4),dpi=120)
    sns.set(context='talk',style='whitegrid',palette='dark',font='monospace',font_scale=0.5)
    l1=plt.plot(epoch,acc,label="TRAIN ACCURACY")
    l2=plt.plot(epoch,val_acu,label="TEST ACCURACY")

    plt.setp(l1,color='dodgerblue',marker="p",linewidth=2.1)
    plt.setp(l2,color='greenyellow',marker="v",linewidth=2.1)

    plt.xlabel('\nEPOCH',weight='bold')
    plt.ylabel('ACCURACY\n',weight='bold')
    plt.legend(fancybox=True, framealpha=0.9, shadow=True, borderpad=0.7,bbox_to_anchor=(0., 1.02, 1., .102), loc='lower left',
           ncol=2, mode="expand", borderaxespad=0.1)
    
    plt.show()
    
    
#PLOTTING LOSS VALUES
    print("\nLOSS VALUES")
    plt.figure(figsize=(9,4),dpi=120)
    sns.set(context='talk',style='whitegrid',palette='dark',font='monospace',font_scale=0.5)
    l1=plt.plot(epoch,loss,label="TRAIN LOSS")
    l2=plt.plot(epoch,valid_loss,label="TEST LOSS")

    plt.setp(l1,color='teal',marker="x",linewidth=2.1)
    plt.setp(l2,color='maroon',marker="D",linewidth=2.1)

    plt.xlabel('\nEPOCH',weight='bold')
    plt.ylabel('LOSS\n',weight='bold')
    plt.legend(fancybox=True, framealpha=0.9, shadow=True, borderpad=0.7,bbox_to_anchor=(0., 1.02, 1., .102), loc='lower left',
           ncol=2, mode="expand", borderaxespad=0.1)
    
    plt.show()
    
    print()
# Out:
# AT LEARNING RATE 0.001
# ______________________________
#
# Epoch 1/20
# 72/72 [==============================] - ETA: 0s - loss: 0.1939 - accuracy: 0.8951
# Epoch 00001: val_loss improved from inf to 0.37785, saving model to C:\Users\mishr\CNN\p4_saved_model\garment_MCP_sgd_mometum_nestrov0.001.h5
# 72/72 [==============================] - 44s 609ms/step - loss: 0.1939 - accuracy: 0.8951 - val_loss: 0.3779 - val_accuracy: 0.8611 - lr: 0.0010
# Epoch 2/20
# 72/72 [==============================] - ETA: 0s - loss: 0.1822 - accuracy: 0.9043
# Epoch 00002: val_loss did not improve from 0.37785
# 72/72 [==============================] - 43s 603ms/step - loss: 0.1822 - accuracy: 0.9043 - val_loss: 0.3828 - val_accuracy: 0.8639 - lr: 0.0010
# Epoch 3/20
# 72/72 [==============================] - ETA: 0s - loss: 0.1882 - accuracy: 0.9066
# Epoch 00003: val_loss did not improve from 0.37785
# 72/72 [==============================] - 43s 604ms/step - loss: 0.1882 - accuracy: 0.9066 - val_loss: 0.3847 - val_accuracy: 0.8639 - lr: 0.0010
# Epoch 4/20
# 72/72 [==============================] - ETA: 0s - loss: 0.1762 - accuracy: 0.9020
# Epoch 00004: val_loss did not improve from 0.37785
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 72/72 [==============================] - 47s 653ms/step - loss: 0.1762 - accuracy: 0.9020 - val_loss: 0.3918 - val_accuracy: 0.8639 - lr: 0.0010
# Epoch 5/20
# 72/72 [==============================] - ETA: 0s - loss: 0.1842 - accuracy: 0.9035Restoring model weights from the end of the best epoch.
#
# Epoch 00005: val_loss did not improve from 0.37785
# 72/72 [==============================] - 44s 609ms/step - loss: 0.1842 - accuracy: 0.9035 - val_loss: 0.3910 - val_accuracy: 0.8639 - lr: 1.0000e-04
# Epoch 00005: early stopping
#
# predicting the model performance wrt test dataset
# 12/12 [==============================] - 4s 298ms/step - loss: 0.3779 - accuracy: 0.8611
#
# Prediction_TEST LOSS:	 37.78507709503174
#
# Prediction_TEST ACCURACY:	 86.11111044883728
#
# Accuracy Value
# LOSS VALUES
# AT LEARNING RATE 0.01
# ______________________________
#
# Epoch 1/20
# 72/72 [==============================] - ETA: 0s - loss: 0.2133 - accuracy: 0.8866
# Epoch 00001: val_loss improved from inf to 0.43046, saving model to C:\Users\mishr\CNN\p4_saved_model\garment_MCP_sgd_mometum_nestrov0.01.h5
# 72/72 [==============================] - 47s 655ms/step - loss: 0.2133 - accuracy: 0.8866 - val_loss: 0.4305 - val_accuracy: 0.8417 - lr: 0.0100
# Epoch 2/20
# 72/72 [==============================] - ETA: 0s - loss: 0.2148 - accuracy: 0.8873
# Epoch 00002: val_loss improved from 0.43046 to 0.39887, saving model to C:\Users\mishr\CNN\p4_saved_model\garment_MCP_sgd_mometum_nestrov0.01.h5
# 72/72 [==============================] - 46s 642ms/step - loss: 0.2148 - accuracy: 0.8873 - val_loss: 0.3989 - val_accuracy: 0.8528 - lr: 0.0100
# Epoch 3/20
# 72/72 [==============================] - ETA: 0s - loss: 0.2073 - accuracy: 0.9020
# Epoch 00003: val_loss improved from 0.39887 to 0.38845, saving model to C:\Users\mishr\CNN\p4_saved_model\garment_MCP_sgd_mometum_nestrov0.01.h5
# 72/72 [==============================] - 49s 678ms/step - loss: 0.2073 - accuracy: 0.9020 - val_loss: 0.3884 - val_accuracy: 0.8583 - lr: 0.0100
# Epoch 4/20
# 72/72 [==============================] - ETA: 0s - loss: 0.1710 - accuracy: 0.9043
# Epoch 00004: val_loss did not improve from 0.38845
# 72/72 [==============================] - 48s 673ms/step - loss: 0.1710 - accuracy: 0.9043 - val_loss: 0.4685 - val_accuracy: 0.8806 - lr: 0.0100
# Epoch 5/20
# 72/72 [==============================] - ETA: 0s - loss: 0.1957 - accuracy: 0.9190
# Epoch 00005: val_loss improved from 0.38845 to 0.36703, saving model to C:\Users\mishr\CNN\p4_saved_model\garment_MCP_sgd_mometum_nestrov0.01.h5
# 72/72 [==============================] - 46s 642ms/step - loss: 0.1957 - accuracy: 0.9190 - val_loss: 0.3670 - val_accuracy: 0.8417 - lr: 0.0100
# Epoch 6/20
# 72/72 [==============================] - ETA: 0s - loss: 0.1654 - accuracy: 0.9066
# Epoch 00006: val_loss did not improve from 0.36703
# 72/72 [==============================] - 43s 599ms/step - loss: 0.1654 - accuracy: 0.9066 - val_loss: 0.4088 - val_accuracy: 0.8694 - lr: 0.0100
# Epoch 7/20
# 72/72 [==============================] - ETA: 0s - loss: 0.1930 - accuracy: 0.9105
# Epoch 00007: val_loss did not improve from 0.36703
# 72/72 [==============================] - 43s 601ms/step - loss: 0.1930 - accuracy: 0.9105 - val_loss: 0.4021 - val_accuracy: 0.8306 - lr: 0.0100
# Epoch 8/20
# 72/72 [==============================] - ETA: 0s - loss: 0.1791 - accuracy: 0.8981
# Epoch 00008: val_loss did not improve from 0.36703
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0009999999776482583.
# 72/72 [==============================] - 43s 600ms/step - loss: 0.1791 - accuracy: 0.8981 - val_loss: 0.4217 - val_accuracy: 0.8361 - lr: 0.0100
# Epoch 9/20
# 72/72 [==============================] - ETA: 0s - loss: 0.1841 - accuracy: 0.9020Restoring model weights from the end of the best epoch.
#
# Epoch 00009: val_loss did not improve from 0.36703
# 72/72 [==============================] - 43s 596ms/step - loss: 0.1841 - accuracy: 0.9020 - val_loss: 0.4150 - val_accuracy: 0.8472 - lr: 1.0000e-03
# Epoch 00009: early stopping
#
# predicting the model performance wrt test dataset
# 12/12 [==============================] - 3s 285ms/step - loss: 0.3670 - accuracy: 0.8417
#
# Prediction_TEST LOSS:	 36.70261800289154
#
# Prediction_TEST ACCURACY:	 84.16666388511658
#
# Accuracy Value
# LOSS VALUES
# AT LEARNING RATE 0.025
# ______________________________
#
# Epoch 1/20
# 72/72 [==============================] - ETA: 0s - loss: 0.2050 - accuracy: 0.8981
# Epoch 00001: val_loss improved from inf to 0.40317, saving model to C:\Users\mishr\CNN\p4_saved_model\garment_MCP_sgd_mometum_nestrov0.025.h5
# 72/72 [==============================] - 45s 620ms/step - loss: 0.2050 - accuracy: 0.8981 - val_loss: 0.4032 - val_accuracy: 0.8500 - lr: 0.0250
# Epoch 2/20
# 72/72 [==============================] - ETA: 0s - loss: 0.2292 - accuracy: 0.8850
# Epoch 00002: val_loss did not improve from 0.40317
# 72/72 [==============================] - 45s 620ms/step - loss: 0.2292 - accuracy: 0.8850 - val_loss: 0.4763 - val_accuracy: 0.8278 - lr: 0.0250
# Epoch 3/20
# 72/72 [==============================] - ETA: 0s - loss: 0.2741 - accuracy: 0.8850
# Epoch 00003: val_loss did not improve from 0.40317
# 72/72 [==============================] - 45s 625ms/step - loss: 0.2741 - accuracy: 0.8850 - val_loss: 0.5796 - val_accuracy: 0.7806 - lr: 0.0250
# Epoch 4/20
# 72/72 [==============================] - ETA: 0s - loss: 0.2641 - accuracy: 0.8673
# Epoch 00004: val_loss did not improve from 0.40317
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.002500000037252903.
# 72/72 [==============================] - 47s 655ms/step - loss: 0.2641 - accuracy: 0.8673 - val_loss: 0.4870 - val_accuracy: 0.8083 - lr: 0.0250
# Epoch 5/20
# 72/72 [==============================] - ETA: 0s - loss: 0.2544 - accuracy: 0.8781Restoring model weights from the end of the best epoch.
#
# Epoch 00005: val_loss did not improve from 0.40317
# 72/72 [==============================] - 43s 592ms/step - loss: 0.2544 - accuracy: 0.8781 - val_loss: 0.4535 - val_accuracy: 0.8361 - lr: 0.0025
# Epoch 00005: early stopping
#
# predicting the model performance wrt test dataset
# 12/12 [==============================] - 3s 263ms/step - loss: 0.4032 - accuracy: 0.8500
#
# Prediction_TEST LOSS:	 40.316975116729736
#
# Prediction_TEST ACCURACY:	 85.00000238418579
#
# Accuracy Value
# LOSS VALUES

# %% [markdown]
# **compiling the model with RMSPROP with callbacks**

# %%
lr=(0.001,0.01,0.025)
for i in (lr):
    print("AT LEARNING RATE",i)
    print("__"*15)
    print()     
    opt = RMSprop(learning_rate=i)
    m.compile(optimizer=opt, loss="categorical_crossentropy", metrics=['accuracy'])
    
#defining the callbacks    
    check= MCP(r"C:\Users\mishr\CNN\p4_saved_model\garment_MCP_RMSPROP"+str(i)+".h5",
          monitor='val_loss', verbose=1,save_best_only=True,save_weights_only=False, mode='min')

    early=ESP(monitor='val_loss', min_delta=0, patience=4, verbose=1, mode='min',baseline=None, restore_best_weights=True)

    rlp=RLP(monitor='val_loss',factor=0.1, patience=3, verbose=1, mode='min',min_delta=0)


    cb=[early,check,rlp]
    
#training the dataset
    rmsprp = m.fit(x_train,y_train,batch_size =18,epochs=20,steps_per_epoch=np.floor(len(x_train)//20),
                     validation_data = (x_test, y_test),callbacks=cb)

#predicting the results for test dataset
    print("\npredicting the model performance wrt test dataset")
    prediction= m.evaluate(x_test, y_test)
    prediction 
    print("\nPrediction_TEST LOSS:\t",prediction[0]*100)
    print("\nPrediction_TEST ACCURACY:\t",prediction[1]*100)
    print()
   
    
#visualization
   
    record= rmsprp.history
    loss=record['loss']
    acc=record['accuracy']
    valid_loss=record['val_loss']
    val_acu=record['val_accuracy']
    epoch=range(1,len(loss)+1)
    
    #PLOTTING ACCURACY VALUES
    print('Accuracy Value')
    plt.figure(figsize=(9,4),dpi=120)
    sns.set(context='talk',style='whitegrid',palette='dark',font='monospace',font_scale=0.5)
    l1=plt.plot(epoch,acc,label="TRAIN ACCURACY")
    l2=plt.plot(epoch,val_acu,label="TEST ACCURACY")

    plt.setp(l1,color='yellow',marker="p",linewidth=2.1)
    plt.setp(l2,color='deepskyblue',marker="v",linewidth=2.1)

    plt.xlabel('\nEPOCH',weight='bold')
    plt.ylabel('ACCURACY\n',weight='bold')
    plt.legend(fancybox=True, framealpha=0.9, shadow=True, borderpad=0.7,bbox_to_anchor=(0., 1.02, 1., .102), loc='lower left',
           ncol=2, mode="expand", borderaxespad=0.1)
    
    plt.show()
    
    
#PLOTTING LOSS VALUES
    print("\nLOSS VALUES")
    plt.figure(figsize=(9,4),dpi=120)
    sns.set(context='talk',style='whitegrid',palette='dark',font='monospace',font_scale=0.5)
    l1=plt.plot(epoch,loss,label="TRAIN LOSS")
    l2=plt.plot(epoch,valid_loss,label="TEST LOSS")

    plt.setp(l1,color='lime',marker="x",linewidth=2.1)
    plt.setp(l2,color='orange',marker="D",linewidth=2.1)

    plt.xlabel('\nEPOCH',weight='bold')
    plt.ylabel('LOSS\n',weight='bold')
    plt.legend(fancybox=True, framealpha=0.9, shadow=True, borderpad=0.7,bbox_to_anchor=(0., 1.02, 1., .102), loc='lower left',
           ncol=2, mode="expand", borderaxespad=0.1)
    
    plt.show()
    
    print()
# Out:
# AT LEARNING RATE 0.001
# ______________________________
#
# Epoch 1/20
# 72/72 [==============================] - ETA: 0s - loss: 0.1796 - accuracy: 0.9136
# Epoch 00001: val_loss improved from inf to 0.51722, saving model to C:\Users\mishr\CNN\p4_saved_model\garment_MCP_RMSPROP0.001.h5
# 72/72 [==============================] - 46s 635ms/step - loss: 0.1796 - accuracy: 0.9136 - val_loss: 0.5172 - val_accuracy: 0.8639 - lr: 0.0010
# Epoch 2/20
# 72/72 [==============================] - ETA: 0s - loss: 0.1758 - accuracy: 0.9136
# Epoch 00002: val_loss did not improve from 0.51722
# 72/72 [==============================] - 43s 597ms/step - loss: 0.1758 - accuracy: 0.9136 - val_loss: 0.5455 - val_accuracy: 0.8639 - lr: 0.0010
# Epoch 3/20
# 72/72 [==============================] - ETA: 0s - loss: 0.1646 - accuracy: 0.9144
# Epoch 00003: val_loss did not improve from 0.51722
# 72/72 [==============================] - 43s 595ms/step - loss: 0.1646 - accuracy: 0.9144 - val_loss: 0.5485 - val_accuracy: 0.8583 - lr: 0.0010
# Epoch 4/20
# 72/72 [==============================] - ETA: 0s - loss: 0.1483 - accuracy: 0.9306
# Epoch 00004: val_loss did not improve from 0.51722
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 72/72 [==============================] - 43s 597ms/step - loss: 0.1483 - accuracy: 0.9306 - val_loss: 0.5670 - val_accuracy: 0.8611 - lr: 0.0010
# Epoch 5/20
# 72/72 [==============================] - ETA: 0s - loss: 0.1320 - accuracy: 0.9267Restoring model weights from the end of the best epoch.
#
# Epoch 00005: val_loss did not improve from 0.51722
# 72/72 [==============================] - 43s 598ms/step - loss: 0.1320 - accuracy: 0.9267 - val_loss: 0.5704 - val_accuracy: 0.8611 - lr: 1.0000e-04
# Epoch 00005: early stopping
#
# predicting the model performance wrt test dataset
# 12/12 [==============================] - 3s 245ms/step - loss: 0.5172 - accuracy: 0.8639
#
# Prediction_TEST LOSS:	 51.72249674797058
#
# Prediction_TEST ACCURACY:	 86.38888597488403
#
# Accuracy Value
# LOSS VALUES
# AT LEARNING RATE 0.01
# ______________________________
#
# Epoch 1/20
# 72/72 [==============================] - ETA: 0s - loss: 1.7026 - accuracy: 0.7724
# Epoch 00001: val_loss improved from inf to 0.50750, saving model to C:\Users\mishr\CNN\p4_saved_model\garment_MCP_RMSPROP0.01.h5
# 72/72 [==============================] - 43s 597ms/step - loss: 1.7026 - accuracy: 0.7724 - val_loss: 0.5075 - val_accuracy: 0.7972 - lr: 0.0100
# Epoch 2/20
# 72/72 [==============================] - ETA: 0s - loss: 0.4538 - accuracy: 0.8634
# Epoch 00002: val_loss improved from 0.50750 to 0.35647, saving model to C:\Users\mishr\CNN\p4_saved_model\garment_MCP_RMSPROP0.01.h5
# 72/72 [==============================] - 46s 637ms/step - loss: 0.4538 - accuracy: 0.8634 - val_loss: 0.3565 - val_accuracy: 0.8667 - lr: 0.0100
# Epoch 3/20
# 72/72 [==============================] - ETA: 0s - loss: 0.3243 - accuracy: 0.8812
# Epoch 00003: val_loss did not improve from 0.35647
# 72/72 [==============================] - 43s 593ms/step - loss: 0.3243 - accuracy: 0.8812 - val_loss: 0.4050 - val_accuracy: 0.8583 - lr: 0.0100
# Epoch 4/20
# 72/72 [==============================] - ETA: 0s - loss: 0.2946 - accuracy: 0.9120
# Epoch 00004: val_loss did not improve from 0.35647
# 72/72 [==============================] - 45s 628ms/step - loss: 0.2946 - accuracy: 0.9120 - val_loss: 0.8417 - val_accuracy: 0.8306 - lr: 0.0100
# Epoch 5/20
# 72/72 [==============================] - ETA: 0s - loss: 0.3966 - accuracy: 0.9136
# Epoch 00005: val_loss did not improve from 0.35647
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0009999999776482583.
# 72/72 [==============================] - 46s 634ms/step - loss: 0.3966 - accuracy: 0.9136 - val_loss: 0.4940 - val_accuracy: 0.8806 - lr: 0.0100
# Epoch 6/20
# 72/72 [==============================] - ETA: 0s - loss: 0.1349 - accuracy: 0.9552Restoring model weights from the end of the best epoch.
#
# Epoch 00006: val_loss did not improve from 0.35647
# 72/72 [==============================] - 43s 600ms/step - loss: 0.1349 - accuracy: 0.9552 - val_loss: 0.4248 - val_accuracy: 0.8944 - lr: 1.0000e-03
# Epoch 00006: early stopping
#
# predicting the model performance wrt test dataset
# 12/12 [==============================] - 3s 258ms/step - loss: 0.3565 - accuracy: 0.8667
#
# Prediction_TEST LOSS:	 35.64738929271698
#
# Prediction_TEST ACCURACY:	 86.66666746139526
#
# Accuracy Value
# LOSS VALUES
# AT LEARNING RATE 0.025
# ______________________________
#
# Epoch 1/20
# 72/72 [==============================] - ETA: 0s - loss: 7.1178 - accuracy: 0.5224
# Epoch 00001: val_loss improved from inf to 0.72225, saving model to C:\Users\mishr\CNN\p4_saved_model\garment_MCP_RMSPROP0.025.h5
# 72/72 [==============================] - 44s 610ms/step - loss: 7.1178 - accuracy: 0.5224 - val_loss: 0.7222 - val_accuracy: 0.7000 - lr: 0.0250
# Epoch 2/20
# 72/72 [==============================] - ETA: 0s - loss: 1.8036 - accuracy: 0.6042
# Epoch 00002: val_loss did not improve from 0.72225
# 72/72 [==============================] - 43s 592ms/step - loss: 1.8036 - accuracy: 0.6042 - val_loss: 0.8945 - val_accuracy: 0.5528 - lr: 0.0250
# Epoch 3/20
# 72/72 [==============================] - ETA: 0s - loss: 1.1428 - accuracy: 0.5833
# Epoch 00003: val_loss did not improve from 0.72225
# 72/72 [==============================] - 43s 591ms/step - loss: 1.1428 - accuracy: 0.5833 - val_loss: 0.7223 - val_accuracy: 0.5944 - lr: 0.0250
# Epoch 4/20
# 72/72 [==============================] - ETA: 0s - loss: 1.0891 - accuracy: 0.5887
# Epoch 00004: val_loss improved from 0.72225 to 0.63105, saving model to C:\Users\mishr\CNN\p4_saved_model\garment_MCP_RMSPROP0.025.h5
# 72/72 [==============================] - 43s 594ms/step - loss: 1.0891 - accuracy: 0.5887 - val_loss: 0.6311 - val_accuracy: 0.7472 - lr: 0.0250
# Epoch 5/20
# 72/72 [==============================] - ETA: 0s - loss: 1.6297 - accuracy: 0.6319
# Epoch 00005: val_loss did not improve from 0.63105
# 72/72 [==============================] - 43s 592ms/step - loss: 1.6297 - accuracy: 0.6319 - val_loss: 0.9672 - val_accuracy: 0.3917 - lr: 0.0250
# Epoch 6/20
# 72/72 [==============================] - ETA: 0s - loss: 0.9242 - accuracy: 0.5941
# Epoch 00006: val_loss did not improve from 0.63105
# 72/72 [==============================] - 43s 592ms/step - loss: 0.9242 - accuracy: 0.5941 - val_loss: 0.9156 - val_accuracy: 0.4833 - lr: 0.0250
# Epoch 7/20
# 72/72 [==============================] - ETA: 0s - loss: 0.9857 - accuracy: 0.5563
# Epoch 00007: val_loss did not improve from 0.63105
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.002500000037252903.
# 72/72 [==============================] - 43s 591ms/step - loss: 0.9857 - accuracy: 0.5563 - val_loss: 0.9350 - val_accuracy: 0.4528 - lr: 0.0250
# Epoch 8/20
# 72/72 [==============================] - ETA: 0s - loss: 0.7772 - accuracy: 0.5980Restoring model weights from the end of the best epoch.
#
# Epoch 00008: val_loss did not improve from 0.63105
# 72/72 [==============================] - 42s 589ms/step - loss: 0.7772 - accuracy: 0.5980 - val_loss: 0.8325 - val_accuracy: 0.6694 - lr: 0.0025
# Epoch 00008: early stopping
#
# predicting the model performance wrt test dataset
# 12/12 [==============================] - 3s 250ms/step - loss: 0.6311 - accuracy: 0.7472
#
# Prediction_TEST LOSS:	 63.10532093048096
#
# Prediction_TEST ACCURACY:	 74.72222447395325
#
# Accuracy Value
# LOSS VALUES

# %% [markdown]
# **compiling the model with ADAM  with callbacks**

# %%
lr=(0.001,0.01,0.025)
for i in (lr):
    print("AT LEARNING RATE",i)
    print("__"*15)
    print()     
    opt = Adam(learning_rate=i)
    m.compile(optimizer=opt, loss="categorical_crossentropy", metrics=['accuracy'])
    
#defining the callbacks    
    check= MCP(r"C:\Users\mishr\CNN\p4_saved_model\garment_MCP_ADAM"+str(i)+".h5",
          monitor='val_loss', verbose=1,save_best_only=True,save_weights_only=False, mode='min')

    early=ESP(monitor='val_loss', min_delta=0, patience=4, verbose=1, mode='min',baseline=None, restore_best_weights=True)

    rlp=RLP(monitor='val_loss',factor=0.1, patience=3, verbose=1, mode='min',min_delta=0)


    cb=[early,check,rlp]
    
#training the dataset
    adam = m.fit(x_train,y_train,batch_size =18,epochs=20,steps_per_epoch=np.floor(len(x_train)//20),
                     validation_data = (x_test, y_test),callbacks=cb)

#predicting the results for test dataset
    print("\npredicting the model performance wrt test dataset")
    prediction= m.evaluate(x_test, y_test)
    prediction 
    print("\nPrediction_TEST LOSS:\t",prediction[0]*100)
    print("\nPrediction_TEST ACCURACY:\t",prediction[1]*100)
    print()
       
    
#visualization
   
    record= adam.history
    loss=record['loss']
    acc=record['accuracy']
    valid_loss=record['val_loss']
    val_acu=record['val_accuracy']
    epoch=range(1,len(loss)+1)
    
    #PLOTTING ACCURACY VALUES
    print('Accuracy Value')
    plt.figure(figsize=(9,4),dpi=120)
    sns.set(context='talk',style='whitegrid',palette='dark',font='monospace',font_scale=0.5)
    l1=plt.plot(epoch,acc,label="TRAIN ACCURACY")
    l2=plt.plot(epoch,val_acu,label="TEST ACCURACY")

    plt.setp(l1,color='red',marker="p",linewidth=2.1)
    plt.setp(l2,color='khaki',marker="v",linewidth=2.1)

    plt.xlabel('\nEPOCH',weight='bold')
    plt.ylabel('ACCURACY\n',weight='bold')
    plt.legend(fancybox=True, framealpha=0.9, shadow=True, borderpad=0.7,bbox_to_anchor=(0., 1.02, 1., .102), loc='lower left',
           ncol=2, mode="expand", borderaxespad=0.1)
    
    plt.show()
    
    
#PLOTTING LOSS VALUES
    print("\nLOSS VALUES")
    plt.figure(figsize=(9,4),dpi=120)
    sns.set(context='talk',style='whitegrid',palette='dark',font='monospace',font_scale=0.5)
    l1=plt.plot(epoch,loss,label="TRAIN LOSS")
    l2=plt.plot(epoch,valid_loss,label="TEST LOSS")

    plt.setp(l1,color='darkslategrey',marker="x",linewidth=2.1)
    plt.setp(l2,color='coral',marker="D",linewidth=2.1)

    plt.xlabel('\nEPOCH',weight='bold')
    plt.ylabel('LOSS\n',weight='bold')
    plt.legend(fancybox=True, framealpha=0.9, shadow=True, borderpad=0.7,bbox_to_anchor=(0., 1.02, 1., .102), loc='lower left',
           ncol=2, mode="expand", borderaxespad=0.1)
    
    plt.show()
    
    print()
# Out:
# AT LEARNING RATE 0.001
# ______________________________
#
# Epoch 1/20
# 72/72 [==============================] - ETA: 0s - loss: 0.7325 - accuracy: 0.7160
# Epoch 00001: val_loss improved from inf to 0.58249, saving model to C:\Users\mishr\CNN\p4_saved_model\garment_MCP_ADAM0.001.h5
# 72/72 [==============================] - 43s 592ms/step - loss: 0.7325 - accuracy: 0.7160 - val_loss: 0.5825 - val_accuracy: 0.7389 - lr: 0.0010
# Epoch 2/20
# 72/72 [==============================] - ETA: 0s - loss: 0.6014 - accuracy: 0.7145
# Epoch 00002: val_loss did not improve from 0.58249
# 72/72 [==============================] - 42s 581ms/step - loss: 0.6014 - accuracy: 0.7145 - val_loss: 0.5852 - val_accuracy: 0.7417 - lr: 0.0010
# Epoch 3/20
# 72/72 [==============================] - ETA: 0s - loss: 0.5600 - accuracy: 0.7353
# Epoch 00003: val_loss improved from 0.58249 to 0.54081, saving model to C:\Users\mishr\CNN\p4_saved_model\garment_MCP_ADAM0.001.h5
# 72/72 [==============================] - 42s 585ms/step - loss: 0.5600 - accuracy: 0.7353 - val_loss: 0.5408 - val_accuracy: 0.7417 - lr: 0.0010
# Epoch 4/20
# 72/72 [==============================] - ETA: 0s - loss: 0.5126 - accuracy: 0.7685
# Epoch 00004: val_loss improved from 0.54081 to 0.51988, saving model to C:\Users\mishr\CNN\p4_saved_model\garment_MCP_ADAM0.001.h5
# 72/72 [==============================] - 42s 590ms/step - loss: 0.5126 - accuracy: 0.7685 - val_loss: 0.5199 - val_accuracy: 0.7556 - lr: 0.0010
# Epoch 5/20
# 72/72 [==============================] - ETA: 0s - loss: 0.4771 - accuracy: 0.7832
# Epoch 00005: val_loss improved from 0.51988 to 0.50991, saving model to C:\Users\mishr\CNN\p4_saved_model\garment_MCP_ADAM0.001.h5
# 72/72 [==============================] - 42s 590ms/step - loss: 0.4771 - accuracy: 0.7832 - val_loss: 0.5099 - val_accuracy: 0.7639 - lr: 0.0010
# Epoch 6/20
# 72/72 [==============================] - ETA: 0s - loss: 0.4922 - accuracy: 0.7809
# Epoch 00006: val_loss improved from 0.50991 to 0.48412, saving model to C:\Users\mishr\CNN\p4_saved_model\garment_MCP_ADAM0.001.h5
# 72/72 [==============================] - 43s 591ms/step - loss: 0.4922 - accuracy: 0.7809 - val_loss: 0.4841 - val_accuracy: 0.7667 - lr: 0.0010
# Epoch 7/20
# 72/72 [==============================] - ETA: 0s - loss: 0.4276 - accuracy: 0.8063
# Epoch 00007: val_loss improved from 0.48412 to 0.45285, saving model to C:\Users\mishr\CNN\p4_saved_model\garment_MCP_ADAM0
20
# 72/72 [==============================] - ETA: 0s - loss: 0.1979 - accuracy: 0.9043
# Epoch 00019: val_loss did not improve from 0.31267
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 72/72 [==============================] - 43s 602ms/step - loss: 0.1979 - accuracy: 0.9043 - val_loss: 0.3176 - val_accuracy: 0.8806 - lr: 0.0010
# Epoch 20/20
# 72/72 [==============================] - ETA: 0s - loss: 0.1782 - accuracy: 0.9190
# Epoch 00020: val_loss improved from 0.31267 to 0.30287, saving model to C:\Users\mishr\CNN\p4_saved_model\garment_MCP_ADAM0.001.h5
# 72/72 [==============================] - 44s 605ms/step - loss: 0.1782 - accuracy: 0.9190 - val_loss: 0.3029 - val_accuracy: 0.8750 - lr: 1.0000e-04
#
# predicting the model performance wrt test dataset
# 12/12 [==============================] - 3s 248ms/step - loss: 0.3029 - accuracy: 0.8750
#
# Prediction_TEST LOSS:	 30.28653860092163
#
# Prediction_TEST ACCURACY:	 87.5
#
# Accuracy Value
# LOSS VALUES
# AT LEARNING RATE 0.01
# ______________________________
#
# Epoch 1/20
# 72/72 [==============================] - ETA: 0s - loss: 0.5931 - accuracy: 0.8048
# Epoch 00001: val_loss improved from inf to 0.56275, saving model to C:\Users\mishr\CNN\p4_saved_model\garment_MCP_ADAM0.01.h5
# 72/72 [==============================] - 43s 604ms/step - loss: 0.5931 - accuracy: 0.8048 - val_loss: 0.5628 - val_accuracy: 0.7917 - lr: 0.0100
# Epoch 2/20
# 72/72 [==============================] - ETA: 0s - loss: 0.4287 - accuracy: 0.8403
# Epoch 00002: val_loss improved from 0.56275 to 0.45352, saving model to C:\Users\mishr\CNN\p4_saved_model\garment_MCP_ADAM0.01.h5
# 72/72 [==============================] - 43s 602ms/step - loss: 0.4287 - accuracy: 0.8403 - val_loss: 0.4535 - val_accuracy: 0.8167 - lr: 0.0100
# Epoch 3/20
# 72/72 [==============================] - ETA: 0s - loss: 0.4407 - accuracy: 0.8210
# Epoch 00003: val_loss improved from 0.45352 to 0.34218, saving model to C:\Users\mishr\CNN\p4_saved_model\garment_MCP_ADAM0.01.h5
# 72/72 [==============================] - 43s 602ms/step - loss: 0.4407 - accuracy: 0.8210 - val_loss: 0.3422 - val_accuracy: 0.8472 - lr: 0.0100
# Epoch 4/20
# 72/72 [==============================] - ETA: 0s - loss: 0.3307 - accuracy: 0.8596
# Epoch 00004: val_loss did not improve from 0.34218
# 72/72 [==============================] - 43s 600ms/step - loss: 0.3307 - accuracy: 0.8596 - val_loss: 0.3943 - val_accuracy: 0.8167 - lr: 0.0100
# Epoch 5/20
# 72/72 [==============================] - ETA: 0s - loss: 0.5171 - accuracy: 0.7917
# Epoch 00005: val_loss did not improve from 0.34218
# 72/72 [==============================] - 43s 599ms/step - loss: 0.5171 - accuracy: 0.7917 - val_loss: 0.4283 - val_accuracy: 0.8139 - lr: 0.0100
# Epoch 6/20
# 72/72 [==============================] - ETA: 0s - loss: 0.3211 - accuracy: 0.8596
# Epoch 00006: val_loss did not improve from 0.34218
#
# Epoch 00006: ReduceLROnPlateau reducing learning rate to 0.0009999999776482583.
# 72/72 [==============================] - 44s 605ms/step - loss: 0.3211 - accuracy: 0.8596 - val_loss: 0.4423 - val_accuracy: 0.8278 - lr: 0.0100
# Epoch 7/20
# 72/72 [==============================] - ETA: 0s - loss: 0.2693 - accuracy: 0.8866Restoring model weights from the end of the best epoch.
#
# Epoch 00007: val_loss did not improve from 0.34218
# 72/72 [==============================] - 43s 601ms/step - loss: 0.2693 - accuracy: 0.8866 - val_loss: 0.3843 - val_accuracy: 0.8694 - lr: 1.0000e-03
# Epoch 00007: early stopping
#
# predicting the model performance wrt test dataset
# 12/12 [==============================] - 3s 264ms/step - loss: 0.3422 - accuracy: 0.8472
#
# Prediction_TEST LOSS:	 34.218281507492065
#
# Prediction_TEST ACCURACY:	 84.72222089767456
#
# Accuracy Value
# LOSS VALUES
# AT LEARNING RATE 0.025
# ______________________________
#
# Epoch 1/20
# 72/72 [==============================] - ETA: 0s - loss: 0.9881 - accuracy: 0.6227
# Epoch 00001: val_loss improved from inf to 0.87278, saving model to C:\Users\mishr\CNN\p4_saved_model\garment_MCP_ADAM0.025.h5
# 72/72 [==============================] - 44s 606ms/step - loss: 0.9881 - accuracy: 0.6227 - val_loss: 0.8728 - val_accuracy: 0.5278 - lr: 0.0250
# Epoch 2/20
# 72/72 [==============================] - ETA: 0s - loss: 1.0805 - accuracy: 0.4938
# Epoch 00002: val_loss did not improve from 0.87278
# 72/72 [==============================] - 44s 605ms/step - loss: 1.0805 - accuracy: 0.4938 - val_loss: 0.9519 - val_accuracy: 0.4222 - lr: 0.0250
# Epoch 3/20
# 72/72 [==============================] - ETA: 0s - loss: 0.9818 - accuracy: 0.5131
# Epoch 00003: val_loss did not improve from 0.87278
# 72/72 [==============================] - 43s 601ms/step - loss: 0.9818 - accuracy: 0.5131 - val_loss: 1.0832 - val_accuracy: 0.3389 - lr: 0.0250
# Epoch 4/20
# 72/72 [==============================] - ETA: 0s - loss: 1.0945 - accuracy: 0.3480
# Epoch 00004: val_loss did not improve from 0.87278
#
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.002500000037252903.
# 72/72 [==============================] - 44s 604ms/step - loss: 1.0945 - accuracy: 0.3480 - val_loss: 1.0632 - val_accuracy: 0.4583 - lr: 0.0250
# Epoch 5/20
# 72/72 [==============================] - ETA: 0s - loss: 1.0851 - accuracy: 0.3789Restoring model weights from the end of the best epoch.
#
# Epoch 00005: val_loss did not improve from 0.87278
# 72/72 [==============================] - 44s 606ms/step - loss: 1.0851 - accuracy: 0.3789 - val_loss: 1.0577 - val_accuracy: 0.4833 - lr: 0.0025
# Epoch 00005: early stopping
#
# predicting the model performance wrt test dataset
# 12/12 [==============================] - 3s 257ms/step - loss: 0.8728 - accuracy: 0.5278
#
# Prediction_TEST LOSS:	 87.27770447731018
#
# Prediction_TEST ACCURACY:	 52.77777910232544
#
# Accuracy Value
# LOSS VALUES

# %% [markdown]
# **compiling the model with NADAM with callbacks**

# %%
lr=(0.001,0.01,0.025)
for i in (lr):
    print("AT LEARNING RATE",i)
    print("__"*15)
    print()     
    opt = Nadam(learning_rate=i)
    m.compile(optimizer=opt, loss="categorical_crossentropy", metrics=['accuracy'])
    
#defining the callbacks    
    check= MCP(r"C:\Users\mishr\CNN\p4_saved_model\garment_MCP_nadam"+str(i)+".h5",
          monitor='val_loss', verbose=1,save_best_only=True,save_weights_only=False, mode='min')

    early=ESP(monitor='val_loss', min_delta=0, patience=4, verbose=1, mode='min',baseline=None, restore_best_weights=True)

    rlp=RLP(monitor='val_loss',factor=0.1, patience=3, verbose=1, mode='min',min_delta=0)


    cb=[early,check,rlp]
    
#training the dataset
    nadam = m.fit(x_train,y_train,batch_size =18,epochs=20,steps_per_epoch=np.floor(len(x_train)//20),
                     validation_data = (x_test, y_test),callbacks=cb)

#predicting the results for test dataset
    print("\npredicting the model performance wrt test dataset")
    prediction= m.evaluate(x_test, y_test)
    prediction 
    print("\nPrediction_TEST LOSS:\t",prediction[0]*100)
    print("\nPrediction_TEST ACCURACY:\t",prediction[1]*100)
    print()
    
    
    
   
    
#visualization
   
    record= nadam.history
    loss=record['loss']
    acc=record['accuracy']
    valid_loss=record['val_loss']
    val_acu=record['val_accuracy']
    epoch=range(1,len(loss)+1)
    
    #PLOTTING ACCURACY VALUES
    print('Accuracy Value')
    plt.figure(figsize=(9,4),dpi=120)
    sns.set(context='talk',style='whitegrid',palette='dark',font='monospace',font_scale=0.5)
    l1=plt.plot(epoch,acc,label="TRAIN ACCURACY")
    l2=plt.plot(epoch,val_acu,label="TEST ACCURACY")

    plt.setp(l1,color='fuchsia',marker="p",linewidth=2.1)
    plt.setp(l2,color='greenyellow',marker="v",linewidth=2.1)

    plt.xlabel('\nEPOCH',weight='bold')
    plt.ylabel('ACCURACY\n',weight='bold')
    plt.legend(fancybox=True, framealpha=0.9, shadow=True, borderpad=0.7,bbox_to_anchor=(0., 1.02, 1., .102), loc='lower left',
           ncol=2, mode="expand", borderaxespad=0.1)
    
    plt.show()
    
    
#PLOTTING LOSS VALUES
    print("\nLOSS VALUES")
    plt.figure(figsize=(9,4),dpi=120)
    sns.set(context='talk',style='whitegrid',palette='dark',font='monospace',font_scale=0.5)
    l1=plt.plot(epoch,loss,label="TRAIN LOSS")
    l2=plt.plot(epoch,valid_loss,label="TEST LOSS")

    plt.setp(l1,color='gold',marker="x",linewidth=2.1)
    plt.setp(l2,color='cyan',marker="D",linewidth=2.1)

    plt.xlabel('\nEPOCH',weight='bold')
    plt.ylabel('LOSS\n',weight='bold')
    plt.legend(fancybox=True, framealpha=0.9, shadow=True, borderpad=0.7,bbox_to_anchor=(0., 1.02, 1., .102), loc='lower left',
           ncol=2, mode="expand", borderaxespad=0.1)
    
    plt.show()
    
    print()
# Out:
# AT LEARNING RATE 0.001
# ______________________________
#
# Epoch 1/20
# 72/72 [==============================] - ETA: 0s - loss: 0.8820 - accuracy: 0.6304
# Epoch 00001: val_loss improved from inf to 0.82677, saving model to C:\Users\mishr\CNN\p4_saved_model\garment_MCP_nadam0.001.h5
# 72/72 [==============================] - 44s 617ms/step - loss: 0.8820 - accuracy: 0.6304 - val_loss: 0.8268 - val_accuracy: 0.5694 - lr: 0.0010
# Epoch 2/20
# 72/72 [==============================] - ETA: 0s - loss: 0.7049 - accuracy: 0.6898
# Epoch 00002: val_loss improved from 0.82677 to 0.75251, saving model to C:\Users\mishr\CNN\p4_saved_model\garment_MCP_nadam0.001.h5
# 72/72 [==============================] - 44s 618ms/step - loss: 0.7049 - accuracy: 0.6898 - val_loss: 0.7525 - val_accuracy: 0.6167 - lr: 0.0010
# Epoch 3/20
# 72/72 [==============================] - ETA: 0s - loss: 0.6807 - accuracy: 0.7099
# Epoch 00003: val_loss improved from 0.75251 to 0.67995, saving model to C:\Users\mishr\CNN\p4_saved_model\garment_MCP_nadam0.001.h5
# 72/72 [==============================] - 44s 613ms/step - loss: 0.6807 - accuracy: 0.7099 - val_loss: 0.6799 - val_accuracy: 0.7000 - lr: 0.0010
# Epoch 4/20
# 72/72 [==============================] - ETA: 0s - loss: 0.5522 - accuracy: 0.7423
# Epoch 00004: val_loss improved from 0.67995 to 0.64391, saving model to C:\Users\mishr\CNN\p4_saved_model\garment_MCP_nadam0.001.h5
# 72/72 [==============================] - 44s 617ms/step - loss: 0.5522 - accuracy: 0.7423 - val_loss: 0.6439 - val_accuracy: 0.7028 - lr: 0.0010
# Epoch 5/20
# 72/72 [==============================] - ETA: 0s - loss: 0.5286 - accuracy: 0.7577
# Epoch 00005: val_loss improved from 0.64391 to 0.60332, saving model to C:\Users\mishr\CNN\p4_saved_model\garment_MCP_nadam0
20
# 72/72 [==============================] - ETA: 0s - loss: 0.1883 - accuracy: 0.9136
# Epoch 00016: val_loss did not improve from 0.37898
# 72/72 [==============================] - 45s 621ms/step - loss: 0.1883 - accuracy: 0.9136 - val_loss: 0.3848 - val_accuracy: 0.8667 - lr: 0.0010
# Epoch 17/20
# 72/72 [==============================] - ETA: 0s - loss: 0.1881 - accuracy: 0.9244
# Epoch 00017: val_loss improved from 0.37898 to 0.34852, saving model to C:\Users\mishr\CNN\p4_saved_model\garment_MCP_nadam0.001.h5
# 72/72 [==============================] - 45s 628ms/step - loss: 0.1881 - accuracy: 0.9244 - val_loss: 0.3485 - val_accuracy: 0.8806 - lr: 0.0010
# Epoch 18/20
# 72/72 [==============================] - ETA: 0s - loss: 0.1967 - accuracy: 0.9213
# Epoch 00018: val_loss improved from 0.34852 to 0.31776, saving model to C:\Users\mishr\CNN\p4_saved_model\garment_MCP_nadam0.001.h5
# 72/72 [==============================] - 45s 629ms/step - loss: 0.1967 - accuracy: 0.9213 - val_loss: 0.3178 - val_accuracy: 0.8806 - lr: 0.0010
# Epoch 19/20
# 72/72 [==============================] - ETA: 0s - loss: 0.1861 - accuracy: 0.9252
# Epoch 00019: val_loss did not improve from 0.31776
# 72/72 [==============================] - 44s 617ms/step - loss: 0.1861 - accuracy: 0.9252 - val_loss: 0.3355 - val_accuracy: 0.8694 - lr: 0.0010
# Epoch 20/20
# 72/72 [==============================] - ETA: 0s - loss: 0.1821 - accuracy: 0.9252
# Epoch 00020: val_loss did not improve from 0.31776
# 72/72 [==============================] - 45s 622ms/step - loss: 0.1821 - accuracy: 0.9252 - val_loss: 0.3535 - val_accuracy: 0.8806 - lr: 0.0010
#
# predicting the model performance wrt test dataset
# 12/12 [==============================] - 3s 259ms/step - loss: 0.3535 - accuracy: 0.8806
#
# Prediction_TEST LOSS:	 35.348087549209595
#
# Prediction_TEST ACCURACY:	 88.05555701255798
#
# Accuracy Value
# LOSS VALUES
# AT LEARNING RATE 0.01
# ______________________________
#
# Epoch 1/20
# 72/72 [==============================] - ETA: 0s - loss: 0.4676 - accuracy: 0.8488
# Epoch 00001: val_loss improved from inf to 0.41826, saving model to C:\Users\mishr\CNN\p4_saved_model\garment_MCP_nadam0.01.h5
# 72/72 [==============================] - 45s 619ms/step - loss: 0.4676 - accuracy: 0.8488 - val_loss: 0.4183 - val_accuracy: 0.8194 - lr: 0.0100
# Epoch 2/20
# 72/72 [==============================] - ETA: 0s - loss: 0.4161 - accuracy: 0.8534
# Epoch 00002: val_loss improved from 0.41826 to 0.39308, saving model to C:\Users\mishr\CNN\p4_saved_model\garment_MCP_nadam0.01.h5
# 72/72 [==============================] - 46s 633ms/step - loss: 0.4161 - accuracy: 0.8534 - val_loss: 0.3931 - val_accuracy: 0.8389 - lr: 0.0100
# Epoch 3/20
# 72/72 [==============================] - ETA: 0s - loss: 0.4888 - accuracy: 0.8318
# Epoch 00003: val_loss did not improve from 0.39308
# 72/72 [==============================] - 45s 624ms/step - loss: 0.4888 - accuracy: 0.8318 - val_loss: 0.4569 - val_accuracy: 0.8083 - lr: 0.0100
# Epoch 4/20
# 72/72 [==============================] - ETA: 0s - loss: 0.3773 - accuracy: 0.8634
# Epoch 00004: val_loss did not improve from 0.39308
# 72/72 [==============================] - 45s 622ms/step - loss: 0.3773 - accuracy: 0.8634 - val_loss: 0.5663 - val_accuracy: 0.8500 - lr: 0.0100
# Epoch 5/20
# 72/72 [==============================] - ETA: 0s - loss: 0.6630 - accuracy: 0.8179
# Epoch 00005: val_loss did not improve from 0.39308
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0009999999776482583.
# 72/72 [==============================] - 45s 624ms/step - loss: 0.6630 - accuracy: 0.8179 - val_loss: 0.6314 - val_accuracy: 0.8083 - lr: 0.0100
# Epoch 6/20
# 72/72 [==============================] - ETA: 0s - loss: 0.2896 - accuracy: 0.8827Restoring model weights from the end of the best epoch.
#
# Epoch 00006: val_loss did not improve from 0.39308
# 72/72 [==============================] - 45s 622ms/step - loss: 0.2896 - accuracy: 0.8827 - val_loss: 0.5017 - val_accuracy: 0.8222 - lr: 1.0000e-03
# Epoch 00006: early stopping
#
# predicting the model performance wrt test dataset
# 12/12 [==============================] - 3s 249ms/step - loss: 0.3931 - accuracy: 0.8389
#
# Prediction_TEST LOSS:	 39.30797874927521
#
# Prediction_TEST ACCURACY:	 83.88888835906982
#
# Accuracy Value
# LOSS VALUES
# AT LEARNING RATE 0.025
# ______________________________
#
# Epoch 1/20
# 72/72 [==============================] - ETA: 0s - loss: 1.4225 - accuracy: 0.5910
# Epoch 00001: val_loss improved from inf to 0.90264, saving model to C:\Users\mishr\CNN\p4_saved_model\garment_MCP_nadam0.025.h5
# 72/72 [==============================] - 46s 633ms/step - loss: 1.4225 - accuracy: 0.5910 - val_loss: 0.9026 - val_accuracy: 0.5583 - lr: 0.0250
# Epoch 2/20
# 72/72 [==============================] - ETA: 0s - loss: 0.9364 - accuracy: 0.5162
# Epoch 00002: val_loss improved from 0.90264 to 0.86866, saving model to C:\Users\mishr\CNN\p4_saved_model\garment_MCP_nadam0.025.h5
# 72/72 [==============================] - 45s 623ms/step - loss: 0.9364 - accuracy: 0.5162 - val_loss: 0.8687 - val_accuracy: 0.4889 - lr: 0.0250
# Epoch 3/20
# 72/72 [==============================] - ETA: 0s - loss: 1.3360 - accuracy: 0.3588
# Epoch 00003: val_loss did not improve from 0.86866
# 72/72 [==============================] - 45s 624ms/step - loss: 1.3360 - accuracy: 0.3588 - val_loss: 1.1004 - val_accuracy: 0.3444 - lr: 0.0250
# Epoch 4/20
# 72/72 [==============================] - ETA: 0s - loss: 1.1007 - accuracy: 0.3326
# Epoch 00004: val_loss did not improve from 0.86866
# 72/72 [==============================] - 45s 626ms/step - loss: 1.1007 - accuracy: 0.3326 - val_loss: 1.1017 - val_accuracy: 0.3333 - lr: 0.0250
# Epoch 5/20
# 72/72 [==============================] - ETA: 0s - loss: 1.2208 - accuracy: 0.3272
# Epoch 00005: val_loss did not improve from 0.86866
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.002500000037252903.
# 72/72 [==============================] - 45s 619ms/step - loss: 1.2208 - accuracy: 0.3272 - val_loss: 1.0986 - val_accuracy: 0.3444 - lr: 0.0250
# Epoch 6/20
# 72/72 [==============================] - ETA: 0s - loss: 1.1728 - accuracy: 0.3326Restoring model weights from the end of the best epoch.
#
# Epoch 00006: val_loss did not improve from 0.86866
# 72/72 [==============================] - 45s 621ms/step - loss: 1.1728 - accuracy: 0.3326 - val_loss: 1.0983 - val_accuracy: 0.3444 - lr: 0.0025
# Epoch 00006: early stopping
#
# predicting the model performance wrt test dataset
# 12/12 [==============================] - 3s 251ms/step - loss: 0.8687 - accuracy: 0.4889
#
# Prediction_TEST LOSS:	 86.8657112121582
#
# Prediction_TEST ACCURACY:	 48.88888895511627
#
# Accuracy Value
# LOSS VALUES
